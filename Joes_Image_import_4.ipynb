# %% [markdown]
# <a href="https://colab.research.google.com/github/JF11579/Adelphi/blob/main/Joes_Image_import_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # To do List:
#
# For looop
#
# Identify dupes
#
# change each image to resize the image .
#
# "Pad" the bars to keep the aspect ratio
#
# duplicates
#
# plot image and attach teh populsrity score

# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os

import cv2
from PIL import Image

from google.colab.patches import cv2_imshow

import random
import matplotlib.image as mpimg

# %% [markdown]
# My data files are on google Drive. When I load this Colab notebook it loads every single thing in my Drive. I am looking for a way to tell Colab to only look in specific folder. I know I have read about this.

# %%
train_csv = pd.read_csv("/content/drive/MyDrive/Colab_data/train.csv")
train_csv.head(3)
# Out:
#                                  Id  Subject Focus  ...  Blur  Pawpularity
# 0  0007de18844b0dbbb5e1f607da0606e0              0  ...     0           63
# 1  0009c66b9439883ba2750fb825e1d7db              0  ...     0           42
# 2  0013fd999caf9a3efe1352ca1b0d937e              0  ...     0           28
#
# [3 rows x 14 columns]

# %%
test_csv = pd.read_csv("/content/drive/MyDrive/Colab_data/test.csv")
test_csv.head(3)
# Out:
#                                  Id  Subject Focus  Eyes  ...  Occlusion  Info  Blur
# 0  4128bae22183829d2b5fea10effdb0c3              1     0  ...          1     0     1
# 1  43a2262d7738e3d420d453815151079e              0     1  ...          0     0     0
# 2  4e429cead1848a298432a0acad014c9d              0     0  ...          1     1     1
#
# [3 rows x 13 columns]

# %% [markdown]
# # Plot a singel Image
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# **The Path**
#
# base_path = "/content/drive/MyDrive/Colab_data/train/"

# %%
base_path = "/content/drive/MyDrive/Colab_data/train/"

# %%
first_image = base_path + "0a0da090aa9f0342444a7df4dc250c66.jpg"


img = cv2.imread(first_image)

 
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=393x470 at 0x7F576B42E1D0>

# %%
img

# %%
img.shape
# Out:
# (470, 393, 3)

# %%
#first_image = base_path + "/petfinder-pawpularity-score/train/00a1ae8867e0bb89f061679e1cf29e80.jpg"
#img = cv2.imread(first_image)
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
plt.imshow(img)

# %%
RGB_img

# %% [markdown]
# # Plot Multiple Random Images

# %%
n = 3
test_folder=r'base_path'
for i in range(5):
    
    file = random.choice(os.listdir(base_path))

    image_path= os.path.join(base_path, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %% [markdown]
# ## Remove the x , y axis

# %%
plt.figure(figsize=(20,20))

test_folder=r'base_path'
for i in range(10):
    file = random.choice(os.listdir(base_path))
    image_path= os.path.join(base_path, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,10,i+1)
    #ax.title.set_text(file)
    plt.axis('off')
    plt.imshow(img)

# %% [markdown]
# ### But this is random.  We get a different set each time.

# %%
plt.figure(figsize=(60,60)) # <<===  Not sure this has any effect

test_folder=r'base_path'
for i in range(10):
    file = random.choice(os.listdir(base_path))
    image_path= os.path.join(base_path, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,10,i+1)
    #ax.title.set_text(file)
    plt.axis('off')
    plt.imshow(img)

# %% [markdown]
# # Plot Not Random but First N pics

# %%
'''
Juan from Bogota's code:
images = train['file_path][:16]
labels = train['Pawpularity'][:16]

plt.figure(figsize=(32 ,32))
for it, (image,label) in enumerate(image, lables))
  plt.subplot(4 ,8, it+1)
  img = cv2.imread(image)
  RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(RGB_img)
  plt.axis('off')
  plt.title(f'Pawpopularity: {int(label)}')

'''

# %% [markdown]
# The folder:
#
# \base_path = "/content/drive/MyDrive/Colab_data/train/"
#
# A single pic:
#
# /content/drive/MyDrive/Colab_data/train/0009c66b9439883ba2750fb825e1d7db.jpg

# %%
base_path = "/content/drive/MyDrive/Colab_data/train/"

# %%
list(train_csv)

# %%
labels = train_csv['Pawpularity'].head(16)
labels

# %%
#/content/drive/MyDrive/Colab_data/train/0007de18844b0dbbb5e1f607da0606e0.jpg

# %%
base_path = "/content/drive/MyDrive/Colab_data/train/"
images = base_path['base_path'][:16]
images

# %%
#first_image = base_path + "0a0da090aa9f0342444a7df4dc250c66.jpg"

# %%
images =  base_path['base_path'][:16]
images
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-96d1d52a593d> in <module>()
# ----> 1 images =  base_path['base_path'][:16]
#       2 images
#
# TypeError: string indices must be integers

# %%
base_path = "/content/drive/MyDrive/Colab_data/train"

images = train['file_path][:16]
labels = train['Pawpularity'][:16]

#test_folder=r'base_path'

images = base_path
#labels = train.csv['Pawpopularity'][:16]
labels = train_csv['Pawpularity'].head(16)
#

#images = train['base_path'][:16]
#images = 'train'
# csv /content/drive/MyDrive/Colab_data/train.csv
labels = "/content/drive/MyDrive/Colab_data/train.csv"
labels = labels["Pawpularity"][:16]

plt.figure(figsize=(32 ,32))
for it, (image,label) in enumerate(zip(image, lables)):
  plt.subplot(4 ,8, it+1)
  img = cv2.imread(image)
  RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  plt.imshow(RGB_img)
  plt.axis('off')
  plt.title(f'Pawpopularity: {int(label)}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-48031491dc8d> in <module>()
#       7 #images = base_path['train'][:16]
#       8 images = r'base_path'
# ----> 9 labels = train.csv['Pawpopularity'][:16]
#      10
#      11 #images = train['base_path'][:16]
#
# NameError: name 'train' is not defined

# %%
first_image = base_path + "0a0da090aa9f0342444a7df4dc250c66.jpg"


img = cv2.imread(first_image)

 
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=393x470 at 0x7F576B42E1D0>

# %%
#/content/drive/MyDrive/Colab_data/train.csv
labels = ["/content/drive/MyDrive/Colab_data/train.csv"][:16]
#labels = train.csv["Pawpopularity"][:16]

# %%
labels
# Out:
# ['/content/drive/MyDrive/Colab_data/train.csv']
